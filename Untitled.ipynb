# %%
import zipfile
with zipfile.ZipFile('graph_gexf/ENZYMES.zip', 'r') as zip_ref:
    zip_ref.extractall('graph_gexf')

# %%
# !python3 preprocessing.py --dataset_input_dir graph_gexf/ENZYMES
# Out:
# {'Label': {'channel': 1, 'if_input': True, 'if_reconst': True}, 'degree': {'channel': 1, 'if_input': True, 'if_reconst': True}, 'constant': {'channel': 1, 'if_input': True, 'if_reconst': False}}
# Dataset Scan:-----------------------
# Scanned file :----------------------- 0.0%
# Scanned file :----------------------- 1.6666666666666667%
# Scanned file :----------------------- 3.3333333333333335%
# Scanned file :----------------------- 5.0%
# Scanned file :----------------------- 6.666666666666667%
# Scanned file :----------------------- 8.333333333333334%
# Scanned file :----------------------- 10.0%
# Scanned file :----------------------- 11.666666666666666%
# Scanned file :----------------------- 13.333333333333334%
# Scanned file :----------------------- 15.0%
# Scanned file :----------------------- 16.666666666666668%
# Scanned file :----------------------- 18.333333333333332%
# Scanned file :----------------------- 20.0%
# Scanned file :----------------------- 21.666666666666668%
# Scanned file :----------------------- 23.333333333333332%
# Scanned file :----------------------- 25.0%
# Scanned file :----------------------- 26.666666666666668%
# Scanned file :----------------------- 28.333333333333332%
# Scanned file :----------------------- 30.0%
# Scanned file :----------------------- 31.666666666666668%
# Scanned file :----------------------- 33.333333333333336%
# Scanned file :----------------------- 35.0%
# Scanned file :----------------------- 36.666666666666664%
# Scanned file :----------------------- 38.333333333333336%
# Scanned file :----------------------- 40.0%
# Scanned file :----------------------- 41.666666666666664%
# Scanned file :----------------------- 43.333333333333336%
# Scanned file :----------------------- 45.0%
# Scanned file :----------------------- 46.666666666666664%
# Scanned file :----------------------- 48.333333333333336%
# Scanned file :----------------------- 50.0%
# Scanned file :----------------------- 51.666666666666664%
# Scanned file :----------------------- 53.333333333333336%
# Scanned file :----------------------- 55.0%
# Scanned file :----------------------- 56.666666666666664%
# Scanned file :----------------------- 58.333333333333336%
# Scanned file :----------------------- 60.0%
# Scanned file :----------------------- 61.666666666666664%
# Scanned file :----------------------- 63.333333333333336%
# Scanned file :----------------------- 65.0%
# Scanned file :----------------------- 66.66666666666667%
# Scanned file :----------------------- 68.33333333333333%
# Scanned file :----------------------- 70.0%
# Scanned file :----------------------- 71.66666666666667%
# Scanned file :----------------------- 73.33333333333333%
# Scanned file :----------------------- 75.0%
# Scanned file :----------------------- 76.66666666666667%
# Scanned file :----------------------- 78.33333333333333%
# Scanned file :----------------------- 80.0%
# Scanned file :----------------------- 81.66666666666667%
# Scanned file :----------------------- 83.33333333333333%
# Scanned file :----------------------- 85.0%
# Scanned file :----------------------- 86.66666666666667%
# Scanned file :----------------------- 88.33333333333333%
# Scanned file :----------------------- 90.0%
# Scanned file :----------------------- 91.66666666666667%
# Scanned file :----------------------- 93.33333333333333%
# Scanned file :----------------------- 95.0%
# Scanned file :----------------------- 96.66666666666667%
# Scanned file :----------------------- 98.33333333333333%
# Average number of edges: 62.13666666666666
# Average number of nodes: 32.63333333333333
# Dataset Information:
#  Graph number: 600
#  Attribute Info:
#      Attri 1 number: 3
#      Attri 2 number: 1
#      Attri 3 number: 10
#  Number of Classes: 6
# reconstruct_index:0 2
# input_index:0 1 2
# /mnt/beegfs/projects/parkinson_gait/M2_DS_22_23/GraphCaps/preprocessing.py:195: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   adj_mat = nx.adjacency_matrix(graph).todense().astype(float)
# processed file : 0.0%
# processed file : 1.6666666666666667%
# processed file : 3.3333333333333335%
# processed file : 5.0%
# processed file : 6.666666666666667%
# processed file : 8.333333333333334%
# processed file : 10.0%
# processed file : 11.666666666666666%
# processed file : 13.333333333333334%
# processed file : 15.0%
# processed file : 16.666666666666668%
# processed file : 18.333333333333332%
# processed file : 20.0%
# processed file : 21.666666666666668%
# processed file : 23.333333333333332%
# processed file : 25.0%
# processed file : 26.666666666666668%
# processed file : 28.333333333333332%
# processed file : 30.0%
# processed file : 31.666666666666668%
# processed file : 33.333333333333336%
# processed file : 35.0%
# processed file : 36.666666666666664%
# processed file : 38.333333333333336%
# processed file : 40.0%
# processed file : 41.666666666666664%
# processed file : 43.333333333333336%
# processed file : 45.0%
# processed file : 46.666666666666664%
# processed file : 48.333333333333336%
# processed file : 50.0%
# processed file : 51.666666666666664%
# processed file : 53.333333333333336%
# processed file : 55.0%
# processed file : 56.666666666666664%
# processed file : 58.333333333333336%
# processed file : 60.0%
# processed file : 61.666666666666664%
# processed file : 63.333333333333336%
# processed file : 65.0%
# processed file : 66.66666666666667%
# processed file : 68.33333333333333%
# processed file : 70.0%
# processed file : 71.66666666666667%
# processed file : 73.33333333333333%
# processed file : 75.0%
# processed file : 76.66666666666667%
# processed file : 78.33333333333333%
# processed file : 80.0%
# processed file : 81.66666666666667%
# processed file : 83.33333333333333%
# processed file : 85.0%
# processed file : 86.66666666666667%
# processed file : 88.33333333333333%
# processed file : 90.0%
# processed file : 91.66666666666667%
# processed file : 93.33333333333333%
# processed file : 95.0%
# processed file : 96.66666666666667%
# processed file : 98.33333333333333%
# Build test index ##################

# %%
# !python3 main.py --dataset_dir data_plk/ENZYMES
# Out:
# Namespace(device=0, dataset_dir='data_plk/ENZYMES', epochs=3000, batch_size=32, iterations=3, seed=12345, node_embedding_size=8, graph_embedding_size=8, num_gcn_channels=2, num_gcn_layers=5, lr=0.001, decay_step=20000, lambda_val=0.5, noise=0.3, Attention=True, reg_scale=0.1, coordinate=False, layer_depth=5, layer_width=2, num_graph_capsules=16)
# device :  cuda:0
# Dataset Information:
#  Graph number: 600
#  Attribute Info:
#      Attri 0 number: 3
#      Attri 1 number: 1
#      Attri 2 number: 10
#  Number of Classes: 6
# Model(
#   (embeddings): ModuleList(
#     (0): Embedding(3, 8)
#     (1): Embedding(1, 8)
#     (2): Embedding(10, 8)
#   )
#   (attention): Attention(
#     (linears): ModuleList(
#       (0): Linear(in_features=80, out_features=9, bias=False)
#       (1): Linear(in_features=9, out_features=1, bias=False)
#     )
#   )
#   (gcn_layers): ModuleList(
#     (0): GCN(
#       (linear1): Linear(in_features=24, out_features=16, bias=True)
#     )
#     (1): GCN(
#       (linear1): Linear(in_features=16, out_features=16, bias=True)
#     )
#     (2): GCN(
#       (linear1): Linear(in_features=16, out_features=16, bias=True)
#     )
#     (3): GCN(
#       (linear1): Linear(in_features=16, out_features=16, bias=True)
#     )
#     (4): GCN(
#       (linear1): Linear(in_features=16, out_features=16, bias=True)
#     )
#   )
#   (graph_capsule): SecondaryCapsuleLayer()
#   (class_capsule): SecondaryCapsuleLayer()
#   (reconstruction_layer_1): Linear(in_features=8, out_features=16, bias=True)
#   (reconstruction_layer_2): Linear(in_features=16, out_features=13, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
# )
# Epoch :  10 loss training:  7.297178894281387 Time :  19
# accuracy train: 0.266667 val: 0.166667 test: 0.283333
# max val : 0.2 test : 0.26666666666666666 on epoch : 6
#
# Epoch :  20 loss training:  6.795223146677017 Time :  36
# accuracy train: 0.379167 val: 0.350000 test: 0.316667
# max val : 0.35 test : 0.31666666666666665 on epoch : 20
#
# ^C
# Traceback (most recent call last):
#   File "/mnt/beegfs/projects/parkinson_gait/M2_DS_22_23/GraphCaps/main.py", line 150, in <module>
#     main()
#   File "/mnt/beegfs/projects/parkinson_gait/M2_DS_22_23/GraphCaps/main.py", line 130, in main
#     test_acc = test(args, model, gd.graphs_dataset_test, gd, 'test')
#   File "/mnt/beegfs/projects/parkinson_gait/M2_DS_22_23/GraphCaps/main.py", line 48, in test
#     attri_descriptors, adj_mats, label, reconstructs, one_epoch = gd.data_gen(dataset, args.batch_size)
#   File "/mnt/beegfs/projects/parkinson_gait/M2_DS_22_23/GraphCaps/GraphDataset.py", line 82, in data_gen
#     graph = pickle.load(f)
#   File "/mnt/beegfs/home/salembien/miniconda3/envs/notebook/lib/python3.10/site-packages/scipy/sparse/_base.py", line 749, in __getattr__
#     def __getattr__(self, attr):
# KeyboardInterrupt
